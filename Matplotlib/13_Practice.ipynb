# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6,7,8,9]
y=[2,3,1,6,8,4,5,6,3]
x1=[1,2,7,4,6,8,5,2]
x2=[4,2,3,4,5,7,4,3,2,4]
x3=[3,4,1,4,2,4,5,7,5,4]
x4=[3,4,3,2,3,5,5,6,7,6,4]
x5=[2,2,5,3,6,2,3,2]
x6=[1,4,3,7,4,3,6,4]
x7=[2,4,2,5,5,7,5,4]

# %%
plt.plot(x,color="C0")
plt.plot(y,color="C1")
plt.plot(x1,color="C2")
plt.plot(x2,color="C3")
plt.plot(x3,color="C4")
plt.plot(x4,color="C5")
plt.plot(x5,color="C6")
plt.plot(x6,color="C7")
plt.plot(x7,color="C8")

plt.show()
