# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import pyplot as plt

# %% [raw]
# here the %matplotlib is library ans pyplot is the class of that library

# %%
x=["python","java","c","c++"]
y=[30,40,50,60]

# %%
plt.plot(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>
