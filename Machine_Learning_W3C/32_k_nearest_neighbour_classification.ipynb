# %%
# knn - can use for classification ans also for regression but mostly use for classification

# %%
import pandas as pd
df=pd.read_csv("Social_Network_Ads.csv")

# %%
x=df.iloc[:,2:-1];

# %%
x
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
# scale data properly

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
ss.fit(x)
# Out:
# StandardScaler()

# %%
ss.transform(x)
# Out:
# array([[-1.78179743, -1.49004624],
#        [-0.25358736, -1.46068138],
#        [-1.11320552, -0.78528968],
#        [-1.01769239, -0.37418169],
#        [-1.78179743,  0.18375059],
#        [-1.01769239, -0.34481683],
#        [-1.01769239,  0.41866944],
#        [-0.54012675,  2.35674998],
#        [-1.20871865, -1.07893824],
#        [-0.25358736, -0.13926283],
#        [-1.11320552,  0.30121002],
#        [-1.11320552, -0.52100597],
#        [-1.6862843 ,  0.47739916],
#        [-0.54012675, -1.51941109],
#        [-1.87731056,  0.35993973],
#        [-0.82666613,  0.30121002],
#        [ 0.89257019, -1.3138571 ],
#        [ 0.70154394, -1.28449224],
#        [ 0.79705706, -1.22576253],
#        [ 0.98808332, -1.19639767],
#        [ 0.70154394, -1.40195167],
#        [ 0.89257019, -0.60910054],
#        [ 0.98808332, -0.84401939],
#        [ 0.70154394, -1.40195167],
#        [ 0.79705706, -1.37258681],
#        [ 0.89257019, -1.46068138],
#        [ 1.08359645, -1.22576253],
# ...

# %%
x=pd.DataFrame(ss.transform(x))

# %%
x
# Out:
#             0         1
# 0   -1.781797 -1.490046
# 1   -0.253587 -1.460681
# 2   -1.113206 -0.785290
# 3   -1.017692 -0.374182
# 4   -1.781797  0.183751
# ..        ...       ...
# 395  0.797057 -0.844019
# 396  1.274623 -1.372587
# 397  1.179110 -1.460681
# 398 -0.158074 -1.078938
# 399  1.083596 -0.990844
#
# [400 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=43)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=33);
# default k_neighbour is 5

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=33)

# %%
knn.score(x_train,y_train)
# Out:
# 0.9066666666666666

# %%
knn.score(x_test,y_test)
# Out:
# 0.86

# %%
from mlxtend.plotting import plot_decision_regions
import numpy as np
import matplotlib.pyplot as plt

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=knn)
plt.show()

# %%
# finding best value for k 
for i in range(1,40):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    print(knn.score(x_train,y_train), " ", knn.score(x_test,y_test) ," - " ,i)
# Out:
# 1.0   0.83  -  1
# 0.9433333333333334   0.79  -  2
# 0.9433333333333334   0.86  -  3
# 0.9433333333333334   0.86  -  4
# 0.9433333333333334   0.86  -  5
# 0.94   0.86  -  6
# 0.94   0.85  -  7
# 0.94   0.85  -  8
# 0.9366666666666666   0.86  -  9
# 0.9366666666666666   0.86  -  10
# 0.9333333333333333   0.87  -  11
# 0.9366666666666666   0.85  -  12
# 0.94   0.86  -  13
# 0.92   0.86  -  14
# 0.93   0.86  -  15
# 0.93   0.86  -  16
# 0.9333333333333333   0.86  -  17
# 0.92   0.85  -  18
# 0.9166666666666666   0.86  -  19
# 0.9166666666666666   0.85  -  20
# 0.9233333333333333   0.85  -  21
# 0.9166666666666666   0.85  -  22
# 0.9133333333333333   0.85  -  23
# 0.91   0.85  -  24
# 0.9133333333333333   0.85  -  25
# 0.9066666666666666   0.85  -  26
# 0.91   0.85  -  27
# 0.9066666666666666   0.85  -  28
# 0.9066666666666666   0.85  -  29
# 0.9066666666666666   0.85  -  30
# 0.9066666666666666   0.85  -  31
# 0.9066666666666666   0.86  -  32
# 0.9066666666666666   0.86  -  33
# ...

# %%
# 33 is best k value for getting accurate valeu
