# %%
import pandas as pd

# %%
df=pd.read_csv("Salary_Data.csv")

# %%
df
# Out:
#     YearsExperience   Age  Salary
# 0               1.1  21.0   39343
# 1               1.3  21.5   46205
# 2               1.5  21.7   37731
# 3               2.0  22.0   43525
# 4               2.2  22.2   39891
# 5               2.9  23.0   56642
# 6               3.0  23.0   60150
# 7               3.2  23.3   54445
# 8               3.2  23.3   64445
# 9               3.7  23.6   57189
# 10              3.9  23.9   63218
# 11              4.0  24.0   55794
# 12              4.0  24.0   56957
# 13              4.1  24.0   57081
# 14              4.5  25.0   61111
# 15              4.9  25.0   67938
# 16              5.1  26.0   66029
# 17              5.3  27.0   83088
# 18              5.9  28.0   81363
# 19              6.0  29.0   93940
# 20              6.8  30.0   91738
# 21              7.1  30.0   98273
# 22              7.9  31.0  101302
# 23              8.2  32.0  113812
# 24              8.7  33.0  109431
# 25              9.0  34.0  105582
# 26              9.5  35.0  116969
# 27              9.6  36.0  112635
# 28             10.3  37.0  122391
# 29             10.5  38.0  121872

# %%
x=df.iloc[:,:-1]

# %%
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=43)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn=KNeighborsRegressor(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
knn.score(x_test,y_test)
# Out:
# 0.9001466760877329

# %%
knn.score(x_train,y_train)
# Out:
# 0.976679038386825

# %%
# finding the accurate n-neighbor value 
for i in range(1,20):
    knn=KNeighborsRegressor(n_neighbors=i)
    knn.fit(x_train,y_train)
    print(knn.score(x_test,y_test)," ",knn.score(x_train,y_train),'- ', i)
# Out:
# 0.9494773431448336   1.0 -  1
# 0.9242658032450614   0.9801699903936111 -  2
# 0.8994055538062049   0.9808383104128273 -  3
# 0.9172827999930127   0.9804448337542468 -  4
# 0.9001466760877329   0.976679038386825 -  5
# 0.8580438992223733   0.9766943574832596 -  6
# 0.8372515128267101   0.9639807081781775 -  7
# 0.8348427995976385   0.9596139572325361 -  8
# 0.887261462264867   0.9428898540205523 -  9
# 0.8652924530230547   0.9301498483996669 -  10
# 0.8722632309607177   0.9111940157167844 -  11
# 0.8986989502765037   0.8881724170890177 -  12
# 0.9272548338957021   0.8490059085337256 -  13
# 0.9372423202764016   0.8046424055790095 -  14
# 0.9196299809088222   0.7539947349112215 -  15
# 0.8707309281499034   0.6946446269838 -  16
# 0.8007969426315527   0.6352401636979285 -  17
# 0.7033763007384228   0.5678916283082049 -  18
# 0.5603334421076467   0.4957182421156251 -  19

# %%
# value of k =12 it may be perfect choice
