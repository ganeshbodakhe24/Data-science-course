# %%
# bagging and random forest is use to get better accuracy by taking differenct set of data

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.datasets import make_moons

# %%
x,y=make_moons(n_samples=1000,noise=0.010)

# %%
data={"x1":x[:,0],"x2":x[:,1],"y":y}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#            x1        x2  y
# 0   -0.580334  0.803770  0
# 1    0.454297  0.894315  0
# 2   -0.177937  0.972758  0
# 3   -0.850910  0.548403  0
# 4   -0.356647  0.913717  0
# ..        ...       ... ..
# 995  1.145570 -0.477881  1
# 996  0.896679  0.437430  0
# 997  0.667979  0.733790  0
# 998  0.074230  0.135615  1
# 999  0.922422 -0.506427  1
#
# [1000 rows x 3 columns]

# %%
x=df.iloc[:,:-1]

# %%
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.40)

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.svm import SVC

# %%
bg=BaggingClassifier(estimator=SVC(),n_estimators=20)

# %%
bg.fit(x_train,y_train)
# Out:
# BaggingClassifier(estimator=SVC(), n_estimators=20)

# %%
bg.score(x_test,y_test)
# Out:
# 1.0

# %%
bg.score(x_train,y_train)
# Out:
# 1.0
