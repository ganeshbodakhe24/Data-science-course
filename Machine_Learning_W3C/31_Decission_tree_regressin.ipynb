# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Salary_Data.csv")

# %%
df
# Out:
#     YearsExperience   Age  Salary
# 0               1.1  21.0   39343
# 1               1.3  21.5   46205
# 2               1.5  21.7   37731
# 3               2.0  22.0   43525
# 4               2.2  22.2   39891
# 5               2.9  23.0   56642
# 6               3.0  23.0   60150
# 7               3.2  23.3   54445
# 8               3.2  23.3   64445
# 9               3.7  23.6   57189
# 10              3.9  23.9   63218
# 11              4.0  24.0   55794
# 12              4.0  24.0   56957
# 13              4.1  24.0   57081
# 14              4.5  25.0   61111
# 15              4.9  25.0   67938
# 16              5.1  26.0   66029
# 17              5.3  27.0   83088
# 18              5.9  28.0   81363
# 19              6.0  29.0   93940
# 20              6.8  30.0   91738
# 21              7.1  30.0   98273
# 22              7.9  31.0  101302
# 23              8.2  32.0  113812
# 24              8.7  33.0  109431
# 25              9.0  34.0  105582
# 26              9.5  35.0  116969
# 27              9.6  36.0  112635
# 28             10.3  37.0  122391
# 29             10.5  38.0  121872

# %%
sns.pairplot(data=df)
plt.show()

# %%
# split the data
x=df.iloc[:,:-1]

# %%
y=df.iloc[:,-1]

# %%
x,y
# Out:
# (    YearsExperience   Age
#  0               1.1  21.0
#  1               1.3  21.5
#  2               1.5  21.7
#  3               2.0  22.0
#  4               2.2  22.2
#  5               2.9  23.0
#  6               3.0  23.0
#  7               3.2  23.3
#  8               3.2  23.3
#  9               3.7  23.6
#  10              3.9  23.9
#  11              4.0  24.0
#  12              4.0  24.0
#  13              4.1  24.0
#  14              4.5  25.0
#  15              4.9  25.0
#  16              5.1  26.0
#  17              5.3  27.0
#  18              5.9  28.0
#  19              6.0  29.0
#  20              6.8  30.0
#  21              7.1  30.0
#  22              7.9  31.0
#  23              8.2  32.0
#  24              8.7  33.0
#  25              9.0  34.0
#  26              9.5  35.0
#  27              9.6  36.0
#  28             10.3  37.0
#  29             10.5  38.0,
#  0      39343
#  1      46205
#  2      37731
#  3      43525
#  4      39891
#  5      56642
#  6      60150
#  7      54445
#  8      64445
#  9      57189
#  10     63218
#  11     55794
#  12     56957
#  13     57081
#  14     61111
#  15     67938
#  16     66029
#  17     83088
#  18     81363
#  19     93940
#  20     91738
#  21     98273
#  22    101302
#  23    113812
#  24    109431
#  25    105582
#  26    116969
#  27    112635
#  28    122391
#  29    121872
#  Name: Salary, dtype: int64)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtr.score(x_train,y_train)
# Out:
# 0.9999532463874449

# %%
dtr.score(x_test,y_test)
# Out:
# 0.8602958459824807

# %%
# model is over fitted

# %%
# to shot decision tree
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(50,40))
plot_tree(dtr)
# Out:
# [Text(0.5714285714285714, 0.9444444444444444, 'x[1] <= 27.0\nsquared_error = 657493675.151\nsamples = 22\nvalue = 70416.409'),
#  Text(0.32142857142857145, 0.8333333333333334, 'x[0] <= 2.55\nsquared_error = 83779968.286\nsamples = 14\nvalue = 52723.0'),
#  Text(0.14285714285714285, 0.7222222222222222, 'x[1] <= 21.6\nsquared_error = 9510987.2\nsamples = 5\nvalue = 41339.0'),
#  Text(0.07142857142857142, 0.6111111111111112, 'x[1] <= 21.25\nsquared_error = 11771761.0\nsamples = 2\nvalue = 42774.0'),
#  Text(0.03571428571428571, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 39343.0'),
#  Text(0.10714285714285714, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 46205.0'),
#  Text(0.21428571428571427, 0.6111111111111112, 'x[1] <= 21.85\nsquared_error = 5715776.889\nsamples = 3\nvalue = 40382.333'),
#  Text(0.17857142857142858, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 37731.0'),
#  Text(0.25, 0.5, 'x[1] <= 22.1\nsquared_error = 3301489.0\nsamples = 2\nvalue = 41708.0'),
#  Text(0.21428571428571427, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 43525.0'),
#  Text(0.2857142857142857, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 39891.0'),
#  Text(0.5, 0.7222222222222222, 'x[1] <= 25.5\nsquared_error = 13044440.247\nsamples = 9\nvalue = 59047.444'),
#  Text(0.4642857142857143, 0.6111111111111112, 'x[0] <= 4.3\nsquared_error = 7820634.938\nsamples = 8\nvalue = 58174.75'),
#  Text(0.42857142857142855, 0.5, 'x[0] <= 3.95\nsquared_error = 7530266.204\nsamples = 7\nvalue = 57755.286'),
#  Text(0.35714285714285715, 0.3888888888888889, 'x[1] <= 23.6\nsquared_error = 11206364.188\nsamples = 4\nvalue = 58613.75'),
#  Text(0.32142857142857145, 0.2777777777777778, 'x[0] <= 3.1\nsquared_error = 5519988.667\nsamples = 3\nvalue = 57079.0'),
#  Text(0.2857142857142857, 0.16666666666666666, 'x[0] <= 2.95\nsquared_error = 3076516.0\nsamples = 2\nvalue = 58396.0'),
#  Text(0.25, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 56642.0'),
#  Text(0.32142857142857145, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 60150.0'),
#  Text(0.35714285714285715, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 54445.0'),
#  Text(0.39285714285714285, 0.2777777777777778, 'squared_error = 0.0\nsamples = 1\nvalue = 63218.0'),
#  Text(0.5, 0.3888888888888889, 'x[0] <= 4.05\nsquared_error = 336034.889\nsamples = 3\nvalue = 56610.667'),
#  Text(0.4642857142857143, 0.2777777777777778, 'squared_error = 338142.25\nsamples = 2\nvalue = 56375.5'),
#  Text(0.5357142857142857, 0.2777777777777778, 'squared_error = 0.0\nsamples = 1\nvalue = 57081.0'),
#  Text(0.5, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 61111.0'),
#  Text(0.5357142857142857, 0.6111111111111112, 'squared_error = 0.0\nsamples = 1\nvalue = 66029.0'),
#  Text(0.8214285714285714, 0.8333333333333334, 'x[0] <= 9.25\nsquared_error = 154907171.859\nsamples = 8\nvalue = 101379.875'),
#  Text(0.7142857142857143, 0.7222222222222222, 'x[0] <= 6.95\nsquared_error = 59888878.222\nsamples = 6\nvalue = 95366.333'),
#  Text(0.6071428571428571, 0.6111111111111112, 'x[1] <= 28.5\nsquared_error = 30074484.222\nsamples = 3\nvalue = 89013.667'),
#  Text(0.5714285714285714, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 81363.0'),
#  Text(0.6428571428571429, 0.5, 'x[0] <= 6.4\nsquared_error = 1212201.0\nsamples = 2\nvalue = 92839.0'),
#  Text(0.6071428571428571, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 93940.0'),
#  Text(0.6785714285714286, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 91738.0'),
#  Text(0.8214285714285714, 0.6111111111111112, 'x[0] <= 8.45\nsquared_error = 8990524.667\nsamples = 3\nvalue = 101719.0'),
#  Text(0.7857142857142857, 0.5, 'x[1] <= 30.5\nsquared_error = 2293710.25\nsamples = 2\nvalue = 99787.5'),
#  Text(0.75, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 98273.0'),
#  Text(0.8214285714285714, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 101302.0'),
#  Text(0.8571428571428571, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 105582.0'),
#  Text(0.9285714285714286, 0.7222222222222222, 'x[1] <= 36.5\nsquared_error = 6009852.25\nsamples = 2\nvalue = 119420.5'),
#  Text(0.8928571428571429, 0.6111111111111112, 'squared_error = 0.0\nsamples = 1\nvalue = 116969.0'),
#  Text(0.9642857142857143, 0.6111111111111112, 'squared_error = 0.0\nsamples = 1\nvalue = 121872.0')]

# %%
# but model is over fit we can fit it by using post pruining

# %%
for i in range(1,20):
    dtr=DecisionTreeRegressor(max_depth=i)
    dtr.fit(x_train,y_train)
    print(dtr.score(x_train,y_train) ," - " ,dtr.score(x_test,y_test)," -- ", i)
# Out:
# 0.8332388430600315  -  0.5587224978914288  --  1
# 0.9629233991606266  -  0.7303000500305741  --  2
# 0.9847595520573043  -  0.882297450772993  --  3
# 0.9954146351906762  -  0.8710395358008851  --  4
# 0.9968313859440858  -  0.8904262974683709  --  5
# 0.9988084053711415  -  0.869915032861864  --  6
# 0.9995278684966794  -  0.8693307583517671  --  7
# 0.9999532463874449  -  0.8693307583517671  --  8
# 0.9999532463874449  -  0.8602958459824807  --  9
# 0.9999532463874449  -  0.8602958459824807  --  10
# 0.9999532463874449  -  0.8693307583517671  --  11
# 0.9999532463874449  -  0.8693307583517671  --  12
# 0.9999532463874449  -  0.8693307583517671  --  13
# 0.9999532463874449  -  0.8602958459824807  --  14
# 0.9999532463874449  -  0.8602958459824807  --  15
# 0.9999532463874449  -  0.8693307583517671  --  16
# 0.9999532463874449  -  0.8693307583517671  --  17
# 0.9999532463874449  -  0.8693307583517671  --  18
# 0.9999532463874449  -  0.8602958459824807  --  19

# %%
# the depth =5 is right ans 
from mlxtend.plotting import plot_decision_regions
